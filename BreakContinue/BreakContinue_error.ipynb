# %%
for i in range(10):

  if i % 2 == 0:
    continue

  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
num=0

while num<10:

  num=num+1

  if num%2==0:

    continue

  print(num)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
num=0

while num<10:
  num+=1

  if num==5:
    break
  print(num)

print('programa terminado')
# Out:
# 1
# 2
# 3
# 4
# programa terminado

# %%
for num in range(1,10):
  if num==5:
    break
  print(num)
print('programa terminado')
# Out:
# 1
# 2
# 3
# 4
# programa terminado

# %%
try:

  n1=int(input('ingrese un numero: '))
  n2=int(input('ingrese un numero: '))

  resultado=n1/n2

  print(resultado)

except ZeroDivisionError :

  print('la division por cero no existe')

except ValueError:

  print('imgrese el valor correcto')
# Out:
# ingrese un numero: 5
# ingrese un numero: 0
# la division por cero no existe
